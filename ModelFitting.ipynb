# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import math
sns.set()
import pystan
import arviz as az
from scipy.integrate import odeint

seed = 1111

# %% [markdown]
# ## Define parameters

# %%
# Choose a value from: 
    #'Pirkanmaa', 'Uusimaa', 'Southwest Finland',
    #'Skåne County', 'Stockholm County', 'Västra Götaland County',
    #'Oslo', 'Vestland', 'Viken'
current_region = 'Oslo'

#############################################################################
D_e = 3 / 7
D_p = 2 / 7
D_i = 5 / 7

r = 0.4

r_a = 0.1 
r_p = 1.25 

#############################################################################
# LFO
M = 3
L = 10

# %% [markdown]
# ## Import dataframes

# %%
df_regions = pd.DataFrame(pd.read_csv('~/Documents/Covid19TrafficAnalysis/DfRegions.csv'))
df_regions
# Out:
#                    region  population critical_week_start_infections  \
# 0               Pirkanmaa      515095                     2020-09-27
# 1                 Uusimaa     1671000                     2020-09-13
# 2       Southwest Finland      478582                     2020-09-27
# 3            Skåne County     1340000                     2020-10-11
# 4        Stockholm County     2344000                     2020-09-13
# 5  Västra Götaland County     1710000                     2020-10-18
# 6                    Oslo      634293                     2020-10-18
# 7                Vestland      636500                     2020-10-18
# 8                   Viken     1213354                     2020-10-18
#
#   critical_week_end_infections
# 0                   2020-11-29
# 1                   2020-11-15
# 2                   2020-11-29
# 3                   2020-12-13
# 4                   2020-11-15
# 5                   2020-12-20
# 6                   2020-12-20
# 7                   2020-12-20
# 8                   2020-12-20

# %%
df_investigated_time_period = pd.DataFrame(pd.read_csv('~/Documents/Covid19TrafficAnalysis/DfInvestigatedTimePeriod.csv'))
df_investigated_time_period
# Out:
#        region last_sunday_of_the_week  infections_week_sum  \
# 0   Pirkanmaa              2020-09-27                   39
# 1   Pirkanmaa              2020-10-04                   94
# 2   Pirkanmaa              2020-10-11                   68
# 3   Pirkanmaa              2020-10-18                   62
# 4   Pirkanmaa              2020-10-25                   94
# ..        ...                     ...                  ...
# 85      Viken              2020-11-22                 1348
# 86      Viken              2020-11-29                 1118
# 87      Viken              2020-12-06                 1203
# 88      Viken              2020-12-13                 1143
# 89      Viken              2020-12-20                 1095
#
#     traffic_retail_average  traffic_supermarket_average  \
# 0                     0.00                         0.00
# 1                     0.01                         0.01
# 2                    -0.02                        -0.01
# 3                     0.00                        -0.02
# 4                    -0.03                        -0.02
# ..                     ...                          ...
# 85                   -0.12                        -0.05
# 86                   -0.04                        -0.02
# 87                   -0.04                         0.07
# 88                    0.01                         0.15
# 89                    0.10                         0.22
#
#     traffic_parks_average  traffic_transit_stations_average  \
# 0                    0.00                              0.00
# 1                   -0.31                             -0.03
# 2                   -0.57                             -0.06
# 3                   -0.36                             -0.11
# 4                   -0.86                             -0.08
# ..                    ...                               ...
# 85                  -0.53                             -0.15
# 86                  -0.52                             -0.15
# 87                  -0.70                             -0.15
# 88                  -0.75                             -0.14
# 89                  -0.82                             -0.12
#
#     traffic_workplaces_average  traffic_residential_average
# 0                         0.00                         0.00
# 1                         0.00                         0.01
# 2                         0.00                         0.02
# 3                        -0.19                         0.04
# 4                         0.00                         0.04
# ..                         ...                          ...
# 85                       -0.08                         0.06
# 86                       -0.08                         0.06
# 87                       -0.06                         0.06
# 88                       -0.05                         0.05
# 89                       -0.07                         0.06
#
# [90 rows x 9 columns]

# %% [markdown]
# ## Quantities which directly come from dataframes

# %%
N = df_regions[(df_regions['region'] == current_region)]['population'].tolist()[0]

df_current = df_investigated_time_period[(df_investigated_time_period['region'] == current_region)]

# Initialize the states
inf0 = df_current['infections_week_sum'].tolist()[0] # Weekly infections during first week
P0 = int(inf0 * D_p)
E0 = int( (1/r) * (D_e / D_p) * P0)
I0 = int((1-r) * (D_i / D_e) * E0)
A0 = int(r * (D_i / D_e) * E0)
R0 = 0
S0 = N - I0 - P0 - A0 - E0 - R0
y0 = [S0, E0, A0, P0, I0, R0]

df_current = df_current.iloc[1:] # The first row can be now removed 

num_data_points = df_current.shape[0]

infections = df_current['infections_week_sum'].tolist()
traffic_retail = df_current['traffic_retail_average'].tolist()
traffic_supermarket = df_current['traffic_supermarket_average'].tolist()
traffic_parks = df_current['traffic_parks_average'].tolist()
traffic_transit_stations = df_current['traffic_transit_stations_average'].tolist()
traffic_workplaces = df_current['traffic_workplaces_average'].tolist()
traffic_residential = df_current['traffic_residential_average'].tolist()

traffic_components = [traffic_retail, traffic_supermarket, traffic_parks,
                      traffic_transit_stations, traffic_workplaces, traffic_residential]
traffic_descriptions = ["Retail traffic", "Supermarket traffic", "Park traffic",
                        "Transit station traffic", "Workplace traffic", "Residential traffic"]
traffic_colors = ["tab:purple", "blue", "green", "red", "tab:orange", "y" ]

date_interval = df_current['last_sunday_of_the_week'].tolist()

# %% [markdown]
# ## Plot the analyzed interval

# %%
fig1, ax1 = plt.subplots(1,figsize=(6.9,2.5))
ax1.scatter(range(1, 1 + num_data_points), infections, marker = '*', color='black', label = 'Training, test data')
ax1.scatter(0, inf0, marker = '*', color='r', label = 'Initialization value')
ax1.legend()

plot_rows = 3
plot_columns = 2

fig, ax = plt.subplots(plot_rows, plot_columns, figsize=(15,13))

for i in range(plot_rows):
    for j in range(plot_columns):
        
        ax[i, j].plot(range(1, 1 + num_data_points), traffic_components[i*plot_columns + j],
                      traffic_colors[i*plot_columns + j], label = traffic_descriptions[i*plot_columns + j]) 
        ax[i, j].legend()


plt.show()

# %% [markdown]
# ## Run the model, smoothening
#
# ### Initialization

# %%
sm = pystan.StanModel(file="./SEAPIR.stan")
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_feedd427e14d26e66c285aa2bd01233f NOW.

# %%
seapir_data = {
    "prior_means":[0,0],
    "prior_stds":[10,10],
    "n_training": num_data_points,
    "n_test": 0,
    "y0": y0,

    "t0": 0,
    "t_training": list(range(1, 1+num_data_points)),
    "t_test": np.empty(0),
    "N": N,

    "D_e": D_e,
    "D_p": D_p,
    "D_i": D_i,
    "r": r,
    "r_a": r_a,
    "r_p": r_p,

    "infections": infections,
    "infections_pred": np.empty(0).astype(int),
    "traffic": traffic_retail,
    "traffic_pred": np.empty(0),
}

# %% [markdown]
# ### Fit the model for each traffic component

# %%
smoothening_fits = [] # fits of different traffic components
smoothening_log_likelihoods = []

def smoothening_fits_all_traffic_components():
    all_fits = []
    log_likelihoods = []
    
    for i in range(6):
        current_traffic = traffic_components[i]
        print("Currently plotting: " + traffic_descriptions[i])
        
        seapir_data['traffic'] = current_traffic
        
        fit = sm.sampling(seapir_data, seed=seed)
        all_fits.append(fit)
        
        loglik_exact = np.empty(4000)
        samples = fit.extract(permuted=True)
        loglik_exact[:] = samples["log_lik_training"].ravel()
        log_likelihoods.append(np.mean(loglik_exact))
    
    return all_fits, log_likelihoods
        
smoothening_fits, smoothening_log_likelihoods = smoothening_fits_all_traffic_components()
# Out:
# Currently plotting: Retail traffic
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# Currently plotting: Supermarket traffic
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# Currently plotting: Park traffic
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:24 of 4000 iterations ended with a divergence (0.6 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# Currently plotting: Transit station traffic
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# Currently plotting: Workplace traffic
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# Currently plotting: Residential traffic
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:24 of 4000 iterations ended with a divergence (0.6 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.

# %% [markdown]
# ### Taking a closer look at values of a specific fit

# %%
# f.e. 3 corresponds transit station traffic
#print(smoothening_fits[3])

# %% [markdown]
# ### Plots

# %%
def plot_smoothening_plots_all(smoothening_fits):
   
    fig, ax1 = plt.subplots(3, 2, figsize=(15,13))
    
    for i in range(plot_rows):
        for j in range(plot_columns):

            k = i*plot_columns + j
            
            current_traffic = traffic_components[k]
            current_description = traffic_descriptions[k]
            current_color = traffic_colors[k]
            current_fit = smoothening_fits[k]

            # First plot
            ret = np.empty((5, num_data_points))
            ret[0, :] = np.quantile(current_fit['infections_hat'], 0.5, axis=0)
            ret[1, :] = np.quantile(current_fit['infections_hat'], 0.25, axis=0)
            ret[2, :] = np.quantile(current_fit['infections_hat'], 0.75, axis=0)
            ret[3, :] = np.quantile(current_fit['infections_hat'], 0.025, axis=0)
            ret[4, :] = np.quantile(current_fit['infections_hat'], 0.975, axis=0)


            color = 'black'
            ax1[i, j].set_ylabel('Infections', color='black')
            ax1[i, j].scatter(range(1,num_data_points+1), infections, marker='*', label='Observed', color='black')

            ax1[i, j].scatter(range(1,num_data_points+1), ret[0, :], marker='*', label='Fitted', color='blue')

            ax1[i, j].fill_between(range(1,num_data_points+1), ret[1, :], ret[2, :], label='50% -interval',color='blue', alpha=0.25)
            ax1[i, j].fill_between(range(1,num_data_points+1), ret[3, :], ret[4, :], label='95% -interval',color='grey', alpha=0.25)

            ax1[i, j].tick_params(axis='y', labelcolor=color)

            handles, labels = ax1[i, 0].get_legend_handles_labels()
            order = [0,1]
            ax1[i, j].legend([handles[idx] for idx in order],[labels[idx] for idx in order])
            ax1[i, j].title.set_text(current_description)
    
    
plot_smoothening_plots_all(smoothening_fits)

# %% [markdown]
# ### Intervals for $c_1$ and $c_2$

# %%
for c in range(6):
    current_fit = smoothening_fits[c]
    
    constant_low = round(np.quantile(current_fit['constant'], 0.025, axis=0), 2)
    constant_high = round(np.quantile(current_fit['constant'], 0.975, axis=0), 2)
    
    slope_low = round(np.quantile(current_fit['traffic_slope'], 0.025, axis=0), 2)
    slope_high = round(np.quantile(current_fit['traffic_slope'], 0.975, axis=0), 2)
    
    print(traffic_descriptions[c])
    print("Constant, 95-interval: [" + str(constant_low) + ", " + str(constant_high) +"]")
    print("Traffic slope, 95-interval: [" + str(slope_low) + ", " + str(slope_high) +"]")
    print("-------------------------------------------")
# Out:
# Retail traffic
# Constant, 95-interval: [1.93, 3.24]
# Traffic slope, 95-interval: [2.16, 13.53]
# -------------------------------------------
# Supermarket traffic
# Constant, 95-interval: [1.38, 1.85]
# Traffic slope, 95-interval: [-13.74, 4.59]
# -------------------------------------------
# Park traffic
# Constant, 95-interval: [0.76, 3.74]
# Traffic slope, 95-interval: [-3.1, 6.42]
# -------------------------------------------
# Transit station traffic
# Constant, 95-interval: [2.19, 3.0]
# Traffic slope, 95-interval: [5.49, 13.46]
# -------------------------------------------
# Workplace traffic
# Constant, 95-interval: [2.09, 2.68]
# Traffic slope, 95-interval: [4.94, 11.24]
# -------------------------------------------
# Residential traffic
# Constant, 95-interval: [2.11, 2.88]
# Traffic slope, 95-interval: [-21.7, -7.99]
# -------------------------------------------

# %% [markdown]
# ### Log likelihood

# %%
print(smoothening_log_likelihoods)
# Out:
# [-63.21556740552117, -66.26657849672739, -66.65511540316353, -58.6752592050886, -58.39935073452849, -58.672188250600925]

# %% [markdown]
# ## Leave future out
#
# ### Initialization

# %%
M = 2 # The last data points
L = 5 # this should be defined automatically

num_lfo_loops = num_data_points - L - M + 1

# %% [markdown]
# ### Fit the model for each traffic component

# %%
lfo_fits = []

def _all_traffic_components(i, M):
    all_fits = []
    
    for j in range(6):
        current_traffic = traffic_components[j]
        print("Currently plotting: " + traffic_descriptions[j])
        
        # Update data for LFO model
        seapir_data_lfo = seapir_data.copy()
        seapir_data_lfo["n_training"]   = i
        seapir_data_lfo["n_test"]       = M
        seapir_data_lfo["t_test"]       = seapir_data["t_training"][i:i+M]
        seapir_data_lfo["t_training"]   = seapir_data["t_training"][:i]
        seapir_data_lfo["traffic_pred"] = current_traffic[i:i+M]
        seapir_data_lfo["traffic"]      = current_traffic[:i]
        seapir_data_lfo["infections_pred"]  = seapir_data["infections"][i:i+M]
        seapir_data_lfo["infections"]   = seapir_data["infections"][:i]

        fit = sm.sampling(seapir_data_lfo)
        all_fits.append(fit)
        
        irhat = fit.summary()['summary_colnames']
        irhat = irhat.index("Rhat")
        irhat = fit.summary()["summary"][:, irhat]
        print("Biggest r-hat-value of the current loop:")
        print(np.nanmax(irhat))
        print("----------------------")

        
    return all_fits 

for i in range(L, num_data_points - M + 1):

    lfo_fits_current = _all_traffic_components(i, M)
    
    lfo_fits.append(lfo_fits_current)
# Out:
# Currently plotting: Retail traffic
# WARNING:pystan:84 of 4000 iterations ended with a divergence (2.1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# Biggest r-hat-value of the current loop:
# 1.0168068809713646
# ----------------------
# Currently plotting: Supermarket traffic
# WARNING:pystan:189 of 4000 iterations ended with a divergence (4.72 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# Biggest r-hat-value of the current loop:
# 1.03658929478876
# ----------------------
# Currently plotting: Park traffic
# WARNING:pystan:51 of 4000 iterations ended with a divergence (1.27 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# Biggest r-hat-value of the current loop:
# 1.0103137603566457
# ----------------------
# Currently plotting: Transit station traffic
# WARNING:pystan:48 of 4000 iterations ended with a divergence (1.2 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# Biggest r-hat-value of the current loop:
# 1.043395294332298
# ----------------------
# Currently plotting: Workplace traffic
# WARNING:pystan:28 of 4000 iterations ended with a divergence (0.7 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# Biggest r-hat-value of the current loop:
# 1.009990092142291
# ----------------------
# Currently plotting: Residential traffic
# WARNING:pystan:189 of 4000 iterations ended with a divergence (4.72 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# Biggest r-hat-value of the current loop:
# 1.0070558598351285
# ----------------------
# Currently plotting: Retail traffic
# WARNING:pystan:11 of 4000 iterations ended with a divergence (0.275 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# Biggest r-hat-value of the current loop:
# 1.0066806341228194
# ----------------------
# Currently plotting: Supermarket traffic
# WARNING:pystan:29 of 4000 iterations ended with a divergence (0.725 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# Biggest r-hat-value of the current loop:
# 1.005335971410885
# ----------------------
# Currently plotting: Park traffic
# WARNING:pystan:40 of 4000 iterations ended with a divergence (1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# Biggest r-hat-value of the current loop:
# 1.0133080078328247
# ----------------------
# Currently plotting: Transit station traffic
# WARNING:pystan:3 of 4000 iterations ended with a divergence (0.075 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# Biggest r-hat-value of the current loop:
# 1.0043614101627625
# ----------------------
# Currently plotting: Workplace traffic
# WARNING:pystan:30 of 4000 iterations ended with a divergence (0.75 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# Biggest r-hat-value of the current loop:
# 1.008223772916279
# ----------------------
# Currently plotting: Residential traffic
# WARNING:pystan:18 of 4000 iterations ended with a divergence (0.45 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# Biggest r-hat-value of the current loop:
# 1.0038301804759617
# ----------------------
# Currently plotting: Retail traffic
# WARNING:pystan:6 of 4000 iterations ended with a divergence (0.15 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# Biggest r-hat-value of the current loop:
# 1.0059511661834823
# ----------------------
# Currently plotting: Supermarket traffic
# Biggest r-hat-value of the current loop:
# 1.0088250384908417
# ----------------------
# Currently plotting: Park traffic
# WARNING:pystan:142 of 4000 iterations ended with a divergence (3.55 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# Biggest r-hat-value of the current loop:
# 1.0076217616314895
# ----------------------
# Currently plotting: Transit station traffic
# WARNING:pystan:4 of 4000 iterations ended with a divergence (0.1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# Biggest r-hat-value of the current loop:
# 1.0082392284107868
# ----------------------
# Currently plotting: Workplace traffic
# WARNING:pystan:5 of 4000 iterations ended with a divergence (0.125 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# Biggest r-hat-value of the current loop:
# 1.002734557090815
# ----------------------
# Currently plotting: Residential traffic
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:969 of 4000 iterations ended with a divergence (24.2 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:Chain 4: E-BFMI = 0.0133
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
# Biggest r-hat-value of the current loop:
# 475.3881437482713
# ----------------------

# %% [markdown]
# ### Taking a closer look at values of a specific fit

# %%
print(lfo_fits[2][3]) # f.e. [0][3] corresponds transit station traffic when L=5
# Out:
# Inference for Stan model: anon_model_feedd427e14d26e66c285aa2bd01233f.
# 4 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=4000.
#
#                     mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# constant            2.52  7.8e-3   0.25   2.05   2.37   2.52   2.66   3.04   1003    1.0
# traffic_slope        8.4    0.08   2.61   3.41   6.83   8.47   9.99  13.69   1002    1.0
# phi_inv             0.07  1.8e-3   0.06   0.01   0.03   0.06   0.09   0.23   1189    1.0
# phi                22.84    0.67  16.96   4.31  11.37  18.13  28.86  69.14    649   1.01
# traffic_coeff[1]    2.52  7.8e-3   0.25   2.05   2.37   2.52   2.66   3.04   1003    1.0
# traffic_coeff[2]     8.4    0.08   2.61   3.41   6.83   8.47   9.99  13.69   1002    1.0
# y[1,1]             6.3e5    4.82  153.2  6.3e5  6.3e5  6.3e5  6.3e5  6.3e5   1011    1.0
# y[2,1]             6.3e5   13.72 437.74  6.3e5  6.3e5  6.3e5  6.3e5  6.3e5   1018    1.0
# y[3,1]             6.3e5   23.08  742.9  6.3e5  6.3e5  6.3e5  6.3e5  6.3e5   1036    1.0
# y[4,1]             6.3e5   25.61 849.08  6.2e5  6.3e5  6.3e5  6.3e5  6.3e5   1099    1.0
# y[5,1]             6.3e5   25.81 909.64  6.2e5  6.2e5  6.3e5  6.3e5  6.3e5   1242    1.0
# y[6,1]             6.2e5   25.36 993.66  6.2e5  6.2e5  6.2e5  6.2e5  6.3e5   1535    1.0
# y[7,1]             6.2e5   25.66 1151.9  6.2e5  6.2e5  6.2e5  6.2e5  6.2e5   2015    1.0
# y[1,2]            589.86    2.23   70.8 463.48 545.59  587.6  629.4  747.9   1011    1.0
# y[2,2]            775.83    4.12 131.64 554.89 691.71 768.03 844.75 1079.0   1022    1.0
# y[3,2]             835.7    4.23 138.52 604.86 747.97 825.48 908.16 1156.0   1071    1.0
# y[4,2]            678.26    1.54  72.75 550.88 632.33 671.99 716.17 843.76   2230    1.0
# y[5,2]            615.04    1.68   84.1 480.11 562.88 605.34 654.39 816.32   2508    1.0
# y[6,2]            603.13    2.47  110.5 434.46 533.22  587.1 653.19 875.59   1997    1.0
# y[7,2]            618.85    3.29 139.96 415.32 531.85 595.03 677.01 956.19   1807    1.0
# y[1,3]            307.46    0.68  21.58 268.16 294.07 307.02 319.72  354.9   1011    1.0
# y[2,3]            423.69    1.79  57.14 325.43 387.51 420.98 454.44 554.24   1019    1.0
# y[3,3]            506.04    2.46  79.41 372.63 455.73 501.07 548.22 687.82   1045    1.0
# y[4,3]            485.69    1.68  59.67 379.66  448.3 481.44 518.33 621.38   1264    1.0
# y[5,3]            440.39    0.94  48.32 357.18 410.58 436.15 464.75 553.64   2640    1.0
# y[6,3]             415.5    1.23  60.24 321.21  378.1 407.82  443.2 561.89   2417    1.0
# y[7,3]            411.85    1.77  78.86  293.1 362.11 399.85 446.66 607.64   1981    1.0
# y[1,4]            207.99    0.63  20.17 171.45 195.45 207.51  219.4 252.54   1011    1.0
# y[2,4]            285.28    1.38  44.08 210.25 257.21 282.98 308.68 386.27   1021    1.0
# y[3,4]            322.91    1.62  52.67 234.75 289.66 319.56 350.48 443.29   1057    1.0
# y[4,4]            282.11    0.78  31.51 225.28 261.94 279.54 298.63  353.5   1619    1.0
# y[5,4]            252.97    0.59  31.12 202.56 233.56 249.71 267.75 327.05   2752    1.0
# y[6,4]            243.77    0.89  40.92  180.6 218.19 237.78 262.77 342.48   2135    1.0
# y[7,4]            246.85    1.22  52.47  169.6 214.01 238.26 269.11 374.37   1864    1.0
# y[1,5]             403.0    0.64  20.32 365.65 390.44  402.7 414.64 447.35   1011    1.0
# y[2,5]            579.07    2.18   69.4 458.46 535.22 576.37  616.7 736.48   1017    1.0
# y[3,5]            725.75    3.44 110.85 538.36 655.38  718.6 783.81 980.03   1036    1.0
# y[4,5]            743.75    2.92  99.28 570.45 681.93  736.1 796.42  968.7   1154    1.0
# y[5,5]            679.28    1.59  73.09 550.81  633.6 672.87 717.32 847.66   2103    1.0
# y[6,5]            632.45    1.63  83.48 499.21  580.7  623.2 671.23 834.96   2612    1.0
# y[7,5]            618.21    2.41 109.93 452.39  549.6 601.47 667.93 887.21   2076    1.0
# y[1,6]            855.89    0.64  20.34 818.24 843.36 855.67 867.61 899.99   1011    1.0
# y[2,6]            2051.3    4.26 135.71 1810.1 1966.6 2047.0 2126.7 2352.5   1014    1.0
# y[3,6]            3630.9   11.36 363.26 3001.1 3400.6 3615.2 3826.9 4451.7   1023    1.0
# y[4,6]            5386.8    19.1 616.54 4324.5 4996.3 5353.2 5716.8 6782.5   1042    1.0
# y[5,6]            7031.6   23.57 779.09 5670.3 6543.7 6987.6 7448.8 8801.6   1092    1.0
# y[6,6]            8542.4   25.05  871.4 7007.0 7993.3 8485.5 9018.2  1.1e4   1211    1.0
# y[7,6]            9991.2   25.13 958.84 8295.9 9381.2 9913.8  1.1e4  1.2e4   1456    1.0
# lambda[1]         727.97    2.22  70.61 600.07 684.06 726.29 767.89 883.88   1011    1.0
# lambda[2]         998.47    4.83 154.28 735.88 900.23 990.41 1080.3 1351.9   1021    1.0
# lambda[3]         1130.2    5.67 184.36 821.63 1013.8 1118.4 1226.6 1551.5   1057    1.0
# lambda[4]         987.39    2.74 110.29 788.47  916.8 978.37 1045.2 1237.2   1619    1.0
# lambda[5]          885.4    2.08 108.91 708.94 817.47 873.99 937.13 1144.6   2752    1.0
# lambda[6]          853.2     3.1 143.23 632.08 763.68 832.22 919.69 1198.6   2135    1.0
# lambda[7]         863.96    4.25 183.63 593.59 749.03  833.9 941.88 1310.3   1864    1.0
# y_hat[1,1]         6.3e5    4.82  153.2  6.3e5  6.3e5  6.3e5  6.3e5  6.3e5   1011    1.0
# y_hat[2,1]         6.3e5   13.72 437.74  6.3e5  6.3e5  6.3e5  6.3e5  6.3e5   1018    1.0
# y_hat[3,1]         6.3e5   23.08  742.9  6.3e5  6.3e5  6.3e5  6.3e5  6.3e5   1036    1.0
# y_hat[4,1]         6.3e5   25.61 849.08  6.2e5  6.3e5  6.3e5  6.3e5  6.3e5   1099    1.0
# y_hat[5,1]         6.3e5   25.81 909.64  6.2e5  6.2e5  6.3e5  6.3e5  6.3e5   1242    1.0
# y_hat[6,1]         6.2e5   25.36 993.66  6.2e5  6.2e5  6.2e5  6.2e5  6.3e5   1535    1.0
# y_hat[7,1]         6.2e5   25.66 1151.9  6.2e5  6.2e5  6.2e5  6.2e5  6.2e5   2015    1.0
# y_hat[8,1]         6.2e5   28.61 1405.0  6.2e5  6.2e5  6.2e5  6.2e5  6.2e5   2412    1.0
# y_hat[9,1]         6.2e5    36.2 1782.5  6.2e5  6.2e5  6.2e5  6.2e5  6.2e5   2425    1.0
# y_hat[1,2]        589.86    2.23   70.8 463.48 545.59  587.6  629.4  747.9   1011    1.0
# y_hat[2,2]        775.83    4.12 131.64 554.89 691.71 768.03 844.75 1079.0   1022    1.0
# y_hat[3,2]         835.7    4.23 138.52 604.86 747.97 825.48 908.16 1156.0   1071    1.0
# y_hat[4,2]        678.26    1.54  72.75 550.88 632.33 671.99 716.17 843.76   2230    1.0
# y_hat[5,2]        615.04    1.68   84.1 480.11 562.88 605.34 654.39 816.32   2508    1.0
# y_hat[6,2]        603.13    2.47  110.5 434.46 533.22  587.1 653.19 875.59   1997    1.0
# y_hat[7,2]        618.85    3.29 139.96 415.32 531.85 595.03 677.01 956.19   1807    1.0
# y_hat[8,2]        621.23    4.26 173.01 382.71 514.14 588.89 688.55 1042.2   1648    1.0
# y_hat[9,2]        663.84    5.18 208.76 386.58 535.87 622.84 740.55 1176.5   1625    1.0
# y_hat[1,3]        307.46    0.68  21.58 268.16 294.07 307.02 319.72  354.9   1011    1.0
# y_hat[2,3]        423.69    1.79  57.14 325.43 387.51 420.98 454.44 554.24   1019    1.0
# y_hat[3,3]        506.04    2.46  79.41 372.63 455.73 501.07 548.22 687.82   1045    1.0
# y_hat[4,3]        485.69    1.68  59.67 379.66  448.3 481.44 518.33 621.38   1264    1.0
# y_hat[5,3]        440.39    0.94  48.32 357.18 410.58 436.15 464.75 553.64   2640    1.0
# y_hat[6,3]         415.5    1.23  60.24 321.21  378.1 407.82  443.2 561.89   2417    1.0
# y_hat[7,3]        411.85    1.77  78.86  293.1 362.11 399.85 446.66 607.64   1981    1.0
# y_hat[8,3]        413.14    2.38  99.64 270.99 351.25 395.42 453.73  653.2   1750    1.0
# y_hat[9,3]        428.48     3.0 122.26 262.15 352.95 405.41 475.45 726.29   1661    1.0
# y_hat[1,4]        207.99    0.63  20.17 171.45 195.45 207.51  219.4 252.54   1011    1.0
# y_hat[2,4]        285.28    1.38  44.08 210.25 257.21 282.98 308.68 386.27   1021    1.0
# y_hat[3,4]        322.91    1.62  52.67 234.75 289.66 319.56 350.48 443.29   1057    1.0
# y_hat[4,4]        282.11    0.78  31.51 225.28 261.94 279.54 298.63  353.5   1619    1.0
# y_hat[5,4]        252.97    0.59  31.12 202.56 233.56 249.71 267.75 327.05   2752    1.0
# y_hat[6,4]        243.77    0.89  40.92  180.6 218.19 237.78 262.77 342.48   2135    1.0
# y_hat[7,4]        246.85    1.22  52.47  169.6 214.01 238.26 269.11 374.37   1864    1.0
# y_hat[8,4]        248.21    1.59  65.34 156.94 207.53 236.29  274.3 405.77   1685    1.0
# y_hat[9,4]        261.69    1.96  79.31 155.25 212.93 246.31  291.3 455.49   1637    1.0
# y_hat[1,5]         403.0    0.64  20.32 365.65 390.44  402.7 414.64 447.35   1011    1.0
# y_hat[2,5]        579.07    2.18   69.4 458.46 535.22 576.37  616.7 736.48   1017    1.0
# y_hat[3,5]        725.75    3.44 110.85 538.36 655.38  718.6 783.81 980.03   1036    1.0
# y_hat[4,5]        743.75    2.92  99.28 570.45 681.93  736.1 796.42  968.7   1154    1.0
# y_hat[5,5]        679.28    1.59  73.09 550.81  633.6 672.87 717.32 847.66   2103    1.0
# y_hat[6,5]        632.45    1.63  83.48 499.21  580.7  623.2 671.23 834.96   2612    1.0
# y_hat[7,5]        618.21    2.41 109.93 452.39  549.6 601.47 667.93 887.21   2076    1.0
# y_hat[8,5]        619.15     3.3 140.32  417.0 532.04 595.15 676.95 956.98   1803    1.0
# y_hat[9,5]        635.07    4.23  173.5 395.69  527.5 602.99 702.58 1054.8   1680    1.0
# y_hat[1,6]        855.89    0.64  20.34 818.24 843.36 855.67 867.61 899.99   1011    1.0
# y_hat[2,6]        2051.3    4.26 135.71 1810.1 1966.6 2047.0 2126.7 2352.5   1014    1.0
# y_hat[3,6]        3630.9   11.36 363.26 3001.1 3400.6 3615.2 3826.9 4451.7   1023    1.0
# y_hat[4,6]        5386.8    19.1 616.54 4324.5 4996.3 5353.2 5716.8 6782.5   1042    1.0
# y_hat[5,6]        7031.6   23.57 779.09 5670.3 6543.7 6987.6 7448.8 8801.6   1092    1.0
# y_hat[6,6]        8542.4   25.05  871.4 7007.0 7993.3 8485.5 9018.2  1.1e4   1211    1.0
# y_hat[7,6]        9991.2   25.13 958.84 8295.9 9381.2 9913.8  1.1e4  1.2e4   1456    1.0
# y_hat[8,6]         1.1e4   25.26 1099.1 9490.1  1.1e4  1.1e4  1.2e4  1.4e4   1894    1.0
# y_hat[9,6]         1.3e4   27.47 1330.3  1.1e4  1.2e4  1.3e4  1.4e4  1.6e4   2345    1.0
# lambda_hat[1]     727.97    2.22  70.61 600.07 684.06 726.29 767.89 883.88   1011    1.0
# lambda_hat[2]     998.47    4.83 154.28 735.88 900.23 990.41 1080.3 1351.9   1021    1.0
# lambda_hat[3]     1130.2    5.67 184.36 821.63 1013.8 1118.4 1226.6 1551.5   1057    1.0
# lambda_hat[4]     987.39    2.74 110.29 788.47  916.8 978.37 1045.2 1237.2   1619    1.0
# lambda_hat[5]      885.4    2.08 108.91 708.94 817.47 873.99 937.13 1144.6   2752    1.0
# lambda_hat[6]      853.2     3.1 143.23 632.08 763.68 832.22 919.69 1198.6   2135    1.0
# lambda_hat[7]     863.96    4.25 183.63 593.59 749.03  833.9 941.88 1310.3   1864    1.0
# lambda_hat[8]     868.74    5.57  228.7  549.3 726.37 827.01 960.06 1420.1   1685    1.0
# lambda_hat[9]      915.9    6.86 277.57 543.38 745.26 862.09 1019.5 1594.2   1637    1.0
# infections_hat[1]  730.3    3.72 206.77  364.0  598.0  715.0  840.0 1204.5   3094    1.0
# infections_hat[2] 997.96    5.83  305.4 481.43  804.0  979.0 1159.0 1689.7   2745    1.0
# infections_hat[3] 1136.2    7.98 372.92  516.0  903.0 1104.0 1317.5 1939.5   2184    1.0
# infections_hat[4] 987.09    4.94 284.96  507.4 808.45  966.0 1128.0 1632.5   3323    1.0
# infections_hat[5] 886.36    4.48 267.39  439.0  719.0  861.0 1019.5 1477.1   3557    1.0
# infections_hat[6] 851.02    5.26 283.75  419.4  674.0  812.5  981.0 1510.5   2906    1.0
# infections_hat[7] 861.55    5.98 315.91  418.0 674.45  818.0  989.0 1575.0   2792    1.0
# infections_hat[8] 867.24    6.22 331.15  385.4  666.0  818.0 1003.0 1680.0   2830    1.0
# infections_hat[9] 919.91    8.21 402.52  390.0  679.0  850.5 1068.5 1906.1   2406    1.0
# log_lik_training  -46.88    0.05    1.6 -50.91 -47.72 -46.56 -45.67 -44.84    919    1.0
# log_lik_pred      -13.98    0.05   2.16 -19.51 -14.91 -13.39 -12.49 -11.36   2228    1.0
# lp__               3.7e4    0.05   1.42  3.7e4  3.7e4  3.7e4  3.7e4  3.7e4    783    1.0
#
# Samples were drawn using NUTS at Thu Mar  4 16:34:17 2021.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %% [markdown]
# ### Plots

# %%
def plot_smoothening_plots_all_pred(lfo_fits, i, M):
    
    fig, ax1 = plt.subplots(3, 2, figsize=(15,13))
    #fig.suptitle('Training data, length: ' + str(training_points), fontsize=16)

    
    for j1 in range(plot_rows):
        for j2 in range(plot_columns):
            
            k = j1*plot_columns + j2

            current_traffic = traffic_components[k]
            current_description = traffic_descriptions[k]
            current_color = traffic_colors[k]
            current_fit = lfo_fits[k]

            # First plot
            ret = np.empty((5, i + M))
            ret[0, :] = np.nanquantile(current_fit['infections_hat'], 0.5, axis=0)
            ret[1, :] = np.nanquantile(current_fit['infections_hat'], 0.25, axis=0)
            ret[2, :] = np.nanquantile(current_fit['infections_hat'], 0.75, axis=0)
            ret[3, :] = np.nanquantile(current_fit['infections_hat'], 0.025, axis=0)
            ret[4, :] = np.nanquantile(current_fit['infections_hat'], 0.975, axis=0)

            color = 'black'
            ax1[j1,j2].set_ylabel('Infections', color='black')
            ax1[j1,j2].scatter(range(1,i+M+1), infections[0:i + M], marker='*', label='Observed', color='black')

            # Draw the test data values
            ax1[j1,j2].scatter(range(1,i+1), ret[0, 0:i], marker='*', label='Fitted', color='blue')
            ax1[j1,j2].fill_between(range(1,i+1), ret[1, 0:i], ret[2, 0:i], label='50% -interval',color='blue', alpha=0.25)
            ax1[j1,j2].fill_between(range(1,i+1), ret[3, 0:i], ret[4, 0:i], label='95% -interval',color='grey', alpha=0.25)

            # Draw the validation data values
            ax1[j1,j2].scatter(range(i+1,i+M+1), ret[0, i:i+M], marker='*', label='Predicted', color='firebrick')
            ax1[j1,j2].fill_between(range(i,i+M+1), ret[1, i-1:i+M], ret[2, i-1:i+M], label='50% -interval',color='red', alpha=0.25)
            ax1[j1,j2].fill_between(range(i,i+M+1), ret[3, i-1:i+M], ret[4, i-1:i+M], label='95% -interval',color='lightsalmon', alpha=0.25)

            handles, labels = ax1[j1, 0].get_legend_handles_labels()
            order = [0,1,4]
            ax1[j1, 0].legend([handles[idx] for idx in order],[labels[idx] for idx in order])
            ax1[j1, 1].legend([handles[idx] for idx in order],[labels[idx] for idx in order])
            ax1[j1, j2].title.set_text(current_description)



for i in range(L, L + M + 1):
        
    plot_smoothening_plots_all_pred(lfo_fits[i-L], i, M)

# %% [markdown]
# ### Intervals for $c_1$ and $c_2$

# %%
for c in range(6):
    for j in range(num_lfo_loops):

        current_fit = lfo_fits[j][c]

        constant_low = round(np.quantile(current_fit['constant'], 0.025, axis=0), 2)
        constant_high = round(np.quantile(current_fit['constant'], 0.975, axis=0), 2)

        slope_low = round(np.quantile(current_fit['traffic_slope'], 0.025, axis=0), 2)
        slope_high = round(np.quantile(current_fit['traffic_slope'], 0.975, axis=0), 2)

        print(traffic_descriptions[c] + ", i=" + str(L + j))
        print("Constant, 95-interval: [" + str(constant_low) + ", " + str(constant_high) +"]")
        print("Traffic slope, 95-interval: [" + str(slope_low) + ", " + str(slope_high) +"]")
        print("-------------------------------------------")
        
    print("-------------------------------------------")
    print("-------------------------------------------")
# Out:
# Retail traffic, i=5
# Constant, 95-interval: [1.68, 2.89]
# Traffic slope, 95-interval: [-2.79, 9.54]
# -------------------------------------------
# Retail traffic, i=6
# Constant, 95-interval: [1.82, 3.06]
# Traffic slope, 95-interval: [-0.31, 11.4]
# -------------------------------------------
# Retail traffic, i=7
# Constant, 95-interval: [1.91, 3.21]
# Traffic slope, 95-interval: [1.4, 12.83]
# -------------------------------------------
# -------------------------------------------
# -------------------------------------------
# Supermarket traffic, i=5
# Constant, 95-interval: [1.64, 2.58]
# Traffic slope, 95-interval: [-8.51, 19.26]
# -------------------------------------------
# Supermarket traffic, i=6
# Constant, 95-interval: [1.66, 2.69]
# Traffic slope, 95-interval: [-5.16, 24.8]
# -------------------------------------------
# Supermarket traffic, i=7
# Constant, 95-interval: [1.39, 2.41]
# Traffic slope, 95-interval: [-12.15, 17.9]
# -------------------------------------------
# -------------------------------------------
# -------------------------------------------
# Park traffic, i=5
# Constant, 95-interval: [0.15, 3.79]
# Traffic slope, 95-interval: [-6.27, 6.22]
# -------------------------------------------
# Park traffic, i=6
# Constant, 95-interval: [0.1, 3.26]
# Traffic slope, 95-interval: [-6.23, 4.66]
# -------------------------------------------
# Park traffic, i=7
# Constant, 95-interval: [0.11, 3.21]
# Traffic slope, 95-interval: [-5.91, 4.64]
# -------------------------------------------
# -------------------------------------------
# -------------------------------------------
# Transit station traffic, i=5
# Constant, 95-interval: [1.71, 2.84]
# Traffic slope, 95-interval: [-2.88, 11.42]
# -------------------------------------------
# Transit station traffic, i=6
# Constant, 95-interval: [1.92, 2.93]
# Traffic slope, 95-interval: [1.07, 12.5]
# -------------------------------------------
# Transit station traffic, i=7
# Constant, 95-interval: [2.05, 3.04]
# Traffic slope, 95-interval: [3.41, 13.67]
# -------------------------------------------
# -------------------------------------------
# -------------------------------------------
# Workplace traffic, i=5
# Constant, 95-interval: [1.75, 2.58]
# Traffic slope, 95-interval: [-3.0, 9.61]
# -------------------------------------------
# Workplace traffic, i=6
# Constant, 95-interval: [1.88, 2.64]
# Traffic slope, 95-interval: [0.49, 10.56]
# -------------------------------------------
# Workplace traffic, i=7
# Constant, 95-interval: [1.91, 2.72]
# Traffic slope, 95-interval: [2.12, 11.56]
# -------------------------------------------
# -------------------------------------------
# -------------------------------------------
# Residential traffic, i=5
# Constant, 95-interval: [1.72, 2.72]
# Traffic slope, 95-interval: [-17.59, 4.94]
# -------------------------------------------
# Residential traffic, i=6
# Constant, 95-interval: [1.78, 2.79]
# Traffic slope, 95-interval: [-19.53, 1.07]
# -------------------------------------------
# Residential traffic, i=7
# Constant, 95-interval: [1.85, 287.18]
# Traffic slope, 95-interval: [-20.57, 3.16]
# -------------------------------------------
# -------------------------------------------
# -------------------------------------------

# %% [markdown]
# ### Log likelihood

# %%
def lfo(fits):
    lfos = [0,0,0,0,0,0]
    
    for c in range(6):
        for j in range(num_lfo_loops):
        
            fit = fits[j][c]

            loglik_exact = np.empty(4000)
            samples = fit.extract(permuted=True)
            loglik_exact[:] = samples["log_lik_pred"].ravel()

            lfos[c] = lfos[c] + np.log(np.nanmean(np.exp(loglik_exact)))
        
    return lfos
        
lfos = lfo(lfo_fits)

print(lfos)
# Out:
# [-45.2828379757385, -50.02468158652062, -49.228136008154976, -41.025337755203154, -40.87868442399888, -41.822332799178426]
